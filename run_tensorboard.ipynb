# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-autoencoder-regression/log/inpainting/plain"

# %%
# %tensorboard --logdir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-autoencoder-regression/log/inpainting/residual"

# %%
# %tensorboard --logdir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-autoencoder-regression/log/denoising/plain"

# %%
# %tensorboard --logdir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-autoencoder-regression/log/denoising/residual"

# %%
# %tensorboard --logdir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-autoencoder-regression/log/super_resolution/plain"

# %%
# %tensorboard --logdir "/content/drive/My Drive/YouTube/youtube-cnn-003-pytorch-unet-autoencoder-regression/log/super_resolution/residual"
