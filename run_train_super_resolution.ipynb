# %% [markdown]
# # Super resolution
# - **bilinear** interpolation
# - **x4** downsampling
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet
# - ResNet
# - SRResNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--train_continue "on" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/unet/super_resolution" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/unet/super_resolution" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/unet/super_resolution" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/resnet/super_resolution" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/resnet/super_resolution" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/resnet/super_resolution" \
--network "resnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "test" \
--train_continue "on" \
--batch_size 4 \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/super_resolution" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/super_resolution" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/super_resolution" \
--network "srresnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 0 \
--learning_type "residual"
# Out:
# mode: test
# learning rate: 1.0000e-04
# batch size: 4
# number of epoch: 300
# task: super_resolution
# opts: ['bilinear', array([4., 0.])]
# network: srresnet
# learning type: residual
# data dir: /content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images
# ckpt dir: /content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/super_resolution
# log dir: /content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/super_resolution
# result dir: /content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/super_resolution
# device: cuda
# 2020-04-05 21:50:58.966632: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# TEST: BATCH 0001 / 0050 | LOSS 0.0027
# TEST: BATCH 0002 / 0050 | LOSS 0.0050
# TEST: BATCH 0003 / 0050 | LOSS 0.0039
# TEST: BATCH 0004 / 0050 | LOSS 0.0032
# TEST: BATCH 0005 / 0050 | LOSS 0.0036
# TEST: BATCH 0006 / 0050 | LOSS 0.0035
# TEST: BATCH 0007 / 0050 | LOSS 0.0037
# TEST: BATCH 0008 / 0050 | LOSS 0.0036
# TEST: BATCH 0009 / 0050 | LOSS 0.0040
# TEST: BATCH 0010 / 0050 | LOSS 0.0039
# TEST: BATCH 0011 / 0050 | LOSS 0.0041
# TEST: BATCH 0012 / 0050 | LOSS 0.0041
# TEST: BATCH 0013 / 0050 | LOSS 0.0040
# TEST: BATCH 0014 / 0050 | LOSS 0.0039
# TEST: BATCH 0015 / 0050 | LOSS 0.0039
# TEST: BATCH 0016 / 0050 | LOSS 0.0038
# TEST: BATCH 0017 / 0050 | LOSS 0.0037
# TEST: BATCH 0018 / 0050 | LOSS 0.0039
# TEST: BATCH 0019 / 0050 | LOSS 0.0038
# TEST: BATCH 0020 / 0050 | LOSS 0.0038
# TEST: BATCH 0021 / 0050 | LOSS 0.0038
# TEST: BATCH 0022 / 0050 | LOSS 0.0038
# TEST: BATCH 0023 / 0050 | LOSS 0.0038
# TEST: BATCH 0024 / 0050 | LOSS 0.0039
# TEST: BATCH 0025 / 0050 | LOSS 0.0039
# TEST: BATCH 0026 / 0050 | LOSS 0.0038
# TEST: BATCH 0027 / 0050 | LOSS 0.0038
# TEST: BATCH 0028 / 0050 | LOSS 0.0038
# TEST: BATCH 0029 / 0050 | LOSS 0.0038
# TEST: BATCH 0030 / 0050 | LOSS 0.0037
# TEST: BATCH 0031 / 0050 | LOSS 0.0038
# TEST: BATCH 0032 / 0050 | LOSS 0.0037
# TEST: BATCH 0033 / 0050 | LOSS 0.0037
# TEST: BATCH 0034 / 0050 | LOSS 0.0038
# TEST: BATCH 0035 / 0050 | LOSS 0.0037
# TEST: BATCH 0036 / 0050 | LOSS 0.0037
# TEST: BATCH 0037 / 0050 | LOSS 0.0037
# TEST: BATCH 0038 / 0050 | LOSS 0.0037
# TEST: BATCH 0039 / 0050 | LOSS 0.0037
# TEST: BATCH 0040 / 0050 | LOSS 0.0037
# TEST: BATCH 0041 / 0050 | LOSS 0.0037
# TEST: BATCH 0042 / 0050 | LOSS 0.0037
# TEST: BATCH 0043 / 0050 | LOSS 0.0037
# TEST: BATCH 0044 / 0050 | LOSS 0.0036
# TEST: BATCH 0045 / 0050 | LOSS 0.0036
# TEST: BATCH 0046 / 0050 | LOSS 0.0036
# TEST: BATCH 0047 / 0050 | LOSS 0.0036
# TEST: BATCH 0048 / 0050 | LOSS 0.0037
# TEST: BATCH 0049 / 0050 | LOSS 0.0037
# TEST: BATCH 0050 / 0050 | LOSS 0.0037
# AVERAGE TEST: BATCH 0050 / 0050 | LOSS 0.0037
