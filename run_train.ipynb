# %% [markdown]
# # Inpainting
# - **random** sampling
# - probability **50%**
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
# --mode "train" \
# --data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
# --ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/inpainting/plain" \
# --log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/inpainting/plain" \
# --result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/inpainting/plain" \
# --network "srresnet" \
# --task "inpainting" \
# --opts "random" 0.5 \
# --learning_type "plain" \

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/inpainting/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/inpainting/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/inpainting/residual" \
--network "srresnet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"

# %% [markdown]
# # Denoising
# - **random** noise
# - sigma **30.0**
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
# --mode "train" \
# --data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
# --ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/denoising/plain" \
# --log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/denoising/plain" \
# --result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/denoising/plain" \
# --network "srresnet" \
# --task "denoising" \
# --opts "random" 30.0 \
# --learning_type "plain"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/dsrresnet/enoising/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/denoising/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/denoising/residual" \
--network "srresnet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %% [markdown]
# # Super resolution
# - **bilinear** interpolation
# - **x4** downsampling
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
# --mode "train" \
# --data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
# --ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/super_resolution/plain" \
# --log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/super_resolution/plain" \
# --result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/super_resolution/plain" \
# --network "srresnet" \
# --task "super_resolution" \
# --opts "bilinear" 4.0 \
# --learning_type "plain"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/super_resolution" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/super_resolution" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/super_resolution" \
--network "srresnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 0 \
--ny 256 \
--nx 256 \
--nch 3
