# %% [markdown]
# # Inpainting
# - **random** sampling
# - probability **50%**
#
# # Learning type
# - residual
#
# # Network
# - UNet
# - ResNet
# - SRResNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/unet/inpainting" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/unet/inpainting" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/unet/inpainting" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"
# Out:
# Streaming output truncated to the last 5000 lines.
# TRAIN: EPOCH 0034 / 0100 | BATCH 0027 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0028 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0029 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0030 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0031 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0032 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0033 / 0050 | LOSS 0.0028
# TRAIN: EPOCH 0034 / 0100 | BATCH 0034 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0035 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0036 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0037 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0038 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0039 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0040 / 0050 | LOSS 0.0029
# TRAIN: EPOCH 0034 / 0100 | BATCH 0041 / 0050 | LOSS 0.0029
# ...

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/resnet/inpainting" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/resnet/inpainting" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/resnet/inpainting" \
--network "resnet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"
# Out:
# mode: train
# learning rate: 1.0000e-03
# batch size: 4
# number of epoch: 100
# task: inpainting
# opts: ['random', array([0.5])]
# network: resnet
# learning type: residual
# data dir: /content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images
# ckpt dir: /content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/resnet/inpainting
# log dir: /content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/resnet/inpainting
# result dir: /content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/resnet/inpainting
# device: cuda
# 2020-04-05 01:07:57.584230: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# TRAIN: EPOCH 0001 / 0100 | BATCH 0001 / 0050 | LOSS 0.2648
# TRAIN: EPOCH 0001 / 0100 | BATCH 0002 / 0050 | LOSS 0.2841
# TRAIN: EPOCH 0001 / 0100 | BATCH 0003 / 0050 | LOSS 0.2589
# TRAIN: EPOCH 0001 / 0100 | BATCH 0004 / 0050 | LOSS 0.2272
# ...

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/inpainting" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/inpainting" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/inpainting" \
--network "srresnet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"

# %% [markdown]
# # Denoising
# - **random** noise
# - sigma **30.0**
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet
# - ResNet
# - SRResNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/unet/denoising" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/unet/denoising" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/unet/denoising" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/resnet/denoising" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/resnet/denoising" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/resnet/denoising" \
--network "resnet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/denoising" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/denoising" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/denoising" \
--network "srresnet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %% [markdown]
# # Super resolution
# - **bilinear** interpolation
# - **x4** downsampling
#
# # Learning type
# - plain
# - residual
#
# # Network
# - UNet
# - ResNet
# - SRResNet

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--train_continue "on" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/unet/super_resolution/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/unet/super_resolution/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/unet/super_resolution/residual" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--train_continue "on" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/resnet/super_resolution/residual" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/resnet/super_resolution/residual" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/resnet/super_resolution/residual" \
--network "resnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"

# %%
# !python "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/train.py" \
--mode "train" \
--data_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/datasets/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/checkpoint/srresnet/super_resolution" \
--log_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/log/srresnet/super_resolution" \
--result_dir "/content/drive/My Drive/YouTube/youtube-cnn-004-pytorch-resnet/result/srresnet/super_resolution" \
--network "srresnet" \
--task "super_resolution" \
--opts "bilinear" 4.0 0 \
--learning_type "residual"
